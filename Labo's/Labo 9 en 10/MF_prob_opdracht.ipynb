# %%
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# **Exercises**:
#
# (you can use markdown cells in your answers for text)
# 1. What is the probability of drawing the ace of spades twice in a row? (Assume that any card drawn on the first draw will be put back in the deck before the second draw.)
# 2. You draw a card from a deck of cards. After replacing the drawn card back in the deck and shuffling thoroughly, what is the probability of drawing the same card again?
# 3. Use $n \choose k$ to calculate the probability of throwing three heads in five coin tosses.
# 4. Create a Python function that calculates the probability of throwing $k$ heads in $n$ coin tosses with the $n \choose k$ formula $\frac{n!}{k!(n - k)!}$. Use this method to calculate the probability of -- in five tosses -- throwing each of zero, one, two, three, four, and five heads.
# 5. Show that by averaging over many dice rolls the average outcome goes to 3.5. Use the same approach as in notebook *MF_prob_labo_1* for the coin flips.
# 6. Consider the multimodal distribution that is presented below and corresponds to a mixture of two Gaussians. Use the sample_mean_calculator function from the second notebook to show that the mean of this distribution is normally distributed.

# %%
m = np.concatenate((np.random.normal(size=5000), np.random.normal(loc = 4.0, size=5000)))

# %%
_ = sns.displot(m, kde=True)

# %%
def sample_mean_calculator(input_dist, sample_size, n_samples):
    sample_means = []
    for i in range(n_samples):
        sample = np.random.choice(input_dist, size=sample_size, replace=False)
        sample_means.append(sample.mean())
    return sample_means

# %% [markdown]
# **Answers**

# %%
#1
print("----------------1----------------")
P1 = 1/52 * 1/52
print(f"Spades in a row: {P1}")

#2
print("\n----------------2----------------")
P2 = 52/52 * 1/52
print(f"Same card in a row: {P2}")

#3
print("\n----------------3----------------")
n = 5
k = 3
p = 0.5
q = 0.5
c = 1

for i in range(k):
    c *= (n-i)/(i+1)

P3 = (c * p ** k * q ** (n - k))/2
print(f"3 heads out of 5: {P3}")

#4
print("\n----------------4----------------")
def combinatoric(n, k):
    p = 0.5
    q = 0.5
    c = 1
    for i in range(k):
        c *= (n-i)/(i+1)

    return (c * p ** k * q ** (n - k))/2

for i in range(0, 6):
    print(f"{i} heads: {combinatoric(5, i)}")


# 5
print("\n----------------5----------------")
n = 10000

rolls = np.random.randint(1, 7, size=n)
average = np.mean(rolls)

print(f"Gemiddelde van {n}x te rollen: {average}")

# 6
print("\n----------------6----------------")
sns.displot(sample_mean_calculator(rolls, 500, 10000), kde=True)
_ = plt.xlim(3, 4)
# Out:
# ----------------1----------------
# Spades in a row: 0.00036982248520710064
#
# ----------------2----------------
# Same card in a row: 0.019230769230769232
#
# ----------------3----------------
# 3 heads out of 5: 0.15625
#
# ----------------4----------------
# 0 heads: 0.015625
# 1 heads: 0.078125
# 2 heads: 0.15625
# 3 heads: 0.15625
# 4 heads: 0.078125
# 5 heads: 0.015625
#
# ----------------5----------------
# Gemiddelde van 10000x te rollen: 3.522
#
# ----------------6----------------
